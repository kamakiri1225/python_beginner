# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.__file__
# Out:
# 'c:\\users\\81801\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\seaborn\\__init__.py'

# %% [markdown]
# # データを読み込む

# %%
df_taitanic = pd.read_csv('train.csv')

# %%
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot('Sex', data=df_taitanic)
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Sex', data=df_taitanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df_taitanic, kind="bar",
    x="Sex", y="Age", hue="Pclass",
    ci="sd", palette="dark", alpha=.6, height=6
)

g.despine(left=True)
g.set_axis_labels("", "Age")
#g.legend.set_title("")

# %%
sns.countplot(x='Sex', data=df_taitanic, hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Sex', data=df_taitanic, hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x=df_taitanic['Pclass'], y=df_taitanic['Age'], data=df_taitanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 大人と子供に分類する

# %%
#年齢の平均値

df_taitanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
df_taitanic[['Age', 'Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
def male_female_child(passenger):
    print(passenger)
    print(type(passenger))
    print('====')
    
male_female_child(1)
# Out:
# 1
# <class 'int'>
# ====

# %%
df_taitanic[['Age', 'Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
def male_female_child(passenger):
    print(passenger)
    print(type(passenger))
    print('====')
    

df_taitanic[['Age', 'Sex']].apply(male_female_child, axis=1)
# Out:
# Age      22
# Sex    male
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age        38
# Sex    female
# Name: 1, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age        26
# Sex    female
# Name: 2, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age        35
# Sex    female
# Name: 3, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age      35
# Sex    male
# Name: 4, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age     NaN
# Sex    male
# Name: 5, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age      54
# Sex    male
# Name: 6, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age       2
# Sex    male
# Name: 7, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age        27
# Sex    female
# Name: 8, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# Age        14
# Sex    female
# Name: 9, dtype: object
# <class 'pandas.core.series.Series'>
# ====
# ...

# %%
def male_female_child(passenger_kari):
    print(passenger_kari)
    print(type(passenger_kari))
    
    age, sex = passenger_kari
#     print(age, sex)
    
    if age < 16:
        return 'child'
    else:
        return sex
    
#     print('====')
    
    
df_taitanic[['Age', 'Sex']].apply(male_female_child, axis=1)
# Out:
# Age      22
# Sex    male
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
# Age        38
# Sex    female
# Name: 1, dtype: object
# <class 'pandas.core.series.Series'>
# Age        26
# Sex    female
# Name: 2, dtype: object
# <class 'pandas.core.series.Series'>
# Age        35
# Sex    female
# Name: 3, dtype: object
# <class 'pandas.core.series.Series'>
# Age      35
# Sex    male
# Name: 4, dtype: object
# <class 'pandas.core.series.Series'>
# Age     NaN
# Sex    male
# Name: 5, dtype: object
# <class 'pandas.core.series.Series'>
# Age      54
# Sex    male
# Name: 6, dtype: object
# <class 'pandas.core.series.Series'>
# Age       2
# Sex    male
# Name: 7, dtype: object
# <class 'pandas.core.series.Series'>
# Age        27
# Sex    female
# Name: 8, dtype: object
# <class 'pandas.core.series.Series'>
# Age        14
# Sex    female
# Name: 9, dtype: object
# <class 'pandas.core.series.Series'>
# Age         4
# Sex    female
# Name: 10, dtype: object
# ...

# %%
def male_female_child(passenger_kari):
    print(passenger_kari[0])
    print(type(passenger_kari))
    
    age, sex = passenger_kari
#     print(age, sex)
    
    if age < 16:
        return 'child'
    else:
        return sex
    
#     print('====')
    
# personというカラム名を作成    
df_taitanic['person'] = df_taitanic[['Age', 'Sex']].apply(male_female_child, axis=1)
# Out:
# 22.0
# <class 'pandas.core.series.Series'>
# 38.0
# <class 'pandas.core.series.Series'>
# 26.0
# <class 'pandas.core.series.Series'>
# 35.0
# <class 'pandas.core.series.Series'>
# 35.0
# <class 'pandas.core.series.Series'>
# nan
# <class 'pandas.core.series.Series'>
# 54.0
# <class 'pandas.core.series.Series'>
# 2.0
# <class 'pandas.core.series.Series'>
# 27.0
# <class 'pandas.core.series.Series'>
# 14.0
# <class 'pandas.core.series.Series'>
# 4.0
# <class 'pandas.core.series.Series'>
# 58.0
# <class 'pandas.core.series.Series'>
# 20.0
# <class 'pandas.core.series.Series'>
# 39.0
# <class 'pandas.core.series.Series'>
# 14.0
# <class 'pandas.core.series.Series'>
# 55.0
# <class 'pandas.core.series.Series'>
# 2.0
# <class 'pandas.core.series.Series'>
# nan
# <class 'pandas.core.series.Series'>
# 31.0
# <class 'pandas.core.series.Series'>
# nan
# <class 'pandas.core.series.Series'>
# 35.0
# <class 'pandas.core.series.Series'>
# 34.0
# <class 'pandas.core.series.Series'>
# 15.0
# ...

# %%
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %% [markdown]
# # データの相関を見る

# %%
# 相関係数
df_taitanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
type(df_taitanic.corr())
# Out:
# pandas.core.frame.DataFrame

# %%
corr = df_taitanic.corr()

plt.figure(figsize=(10, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
fig = sns.FacetGrid(df_taitanic, hue='person', aspect=4)

fig.map(sns.kdeplot, 'Age', shade=True)

fig.set(xlim=(0, df_taitanic['Age'].max() ))

fig.add_legend()

# %%
fig = sns.FacetGrid(df_taitanic, hue='Pclass', aspect=4)

fig.map(sns.kdeplot, 'Age', shade=True)

fig.set(xlim=(0, df_taitanic['Age'].max() ))

fig.add_legend()

# %% [markdown]
# # 家族連れか独りのどちらが生存率が高いのか？

# %%
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic['Alone'] = df_taitanic.SibSp + df_taitanic.Parch
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic['Alone'] = df_taitanic['SibSp'] + df_taitanic['Parch']
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(pd)
# Out:
# module

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import seaborn as sns

# %%
sns.countplot(x='Alone',data=df_taitanic)
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=df_taitanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
df_taitanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(x='Alone',data=df_taitanic, hue='Survived', palette='summer_r')
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
df_taitanic_mean = df_taitanic.groupby('Alone', as_index=False).mean()
df_taitanic_mean
# Out:
#    Alone  PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# 0      0   458.000000  0.303538  2.400372  32.220297  0.000000  0.000000
# 1      1   412.838509  0.552795  1.919255  31.391511  0.763975  0.236025
# 2      2   448.352941  0.578431  2.225490  26.035806  0.872549  1.127451
# 3      3   514.344828  0.724138  2.068966  18.274815  1.344828  1.655172
# 4      4   367.866667  0.200000  2.666667  20.818182  2.133333  1.866667
# 5      5   400.136364  0.136364  2.590909  18.409091  2.818182  2.181818
# 6      6   355.750000  0.333333  3.000000  15.166667  3.250000  2.750000
# 7      7   393.833333  0.000000  3.000000  15.666667  4.333333  2.666667
# 8     10   481.714286  0.000000  3.000000        NaN  8.000000  2.000000
#
#         Fare
# 0  21.242689
# 1  49.894129
# 2  39.692482
# 3  54.864510
# 4  58.094453
# 5  73.722727
# 6  29.366667
# 7  46.900000
# 8  69.550000

# %%
df_taitanic_mean['Survived'] = df_taitanic_mean['Survived']*100

# %%
df_taitanic_mean
# Out:
#    Alone  PassengerId   Survived    Pclass        Age     SibSp     Parch  \
# 0      0   458.000000  30.353818  2.400372  32.220297  0.000000  0.000000
# 1      1   412.838509  55.279503  1.919255  31.391511  0.763975  0.236025
# 2      2   448.352941  57.843137  2.225490  26.035806  0.872549  1.127451
# 3      3   514.344828  72.413793  2.068966  18.274815  1.344828  1.655172
# 4      4   367.866667  20.000000  2.666667  20.818182  2.133333  1.866667
# 5      5   400.136364  13.636364  2.590909  18.409091  2.818182  2.181818
# 6      6   355.750000  33.333333  3.000000  15.166667  3.250000  2.750000
# 7      7   393.833333   0.000000  3.000000  15.666667  4.333333  2.666667
# 8     10   481.714286   0.000000  3.000000        NaN  8.000000  2.000000
#
#         Fare
# 0  21.242689
# 1  49.894129
# 2  39.692482
# 3  54.864510
# 4  58.094453
# 5  73.722727
# 6  29.366667
# 7  46.900000
# 8  69.550000

# %%
sns.barplot(x='Alone', y='Survived', data=df_taitanic_mean)
plt.ylabel('Survived(%)')
# Out:
# Text(0, 0.5, 'Survived(%)')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = df_taitanic_mean['Alone']
men_means = df_taitanic_mean['Survived'].round(1)

x = np.arange(len(labels))  # the label locations
y = np.arange(0, 101, 10)
width = 0.8  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Survived(%)')
ax.set_title('Survived(%)')
ax.set_xticks(x)
ax.set_yticks(y)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

a = [1, 2, 3, 4 ,5 ,6]

plt.plot(a, 'g^')
plt.ylabel('some numbers')
plt.show()

# %%
df_taitanic['Alone'] > 0
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Alone, Length: 891, dtype: bool

# %%
df_taitanic['Alone'].loc[df_taitanic['Alone'] > 0] = 'with Family'
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic['Alone'].loc[df_taitanic['Alone'] == 0] = 'Alone'
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_taitanic.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
pd.unique(df_taitanic['Alone'])
# Out:
# array(['with Family', 'Alone'], dtype=object)

# %%
sns.countplot(x='Alone', data=df_taitanic)
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
sns.countplot(x='Alone', data=df_taitanic, hue='Survived')
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
df_taitanic.groupby('Alone').mean()
# Out:
#              PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Alone
# Alone          458.00000  0.303538  2.400372  32.220297  0.000000  0.000000
# with Family    427.79661  0.505650  2.169492  26.413452  1.316384  0.960452
#
#                   Fare
# Alone
# Alone        21.242689
# with Family  48.832275

# %% [markdown]
# # 男女と年齢別で生存者を確認する

# %%
sns.catplot(x='Sex', y='Age', data=df_taitanic, kind='swarm', hue='Survived')
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Pclass', y='Age', data=df_taitanic, kind='swarm', hue='Survived')
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Pclass', y='Survived', data=df_taitanic, kind='point')

# %%
sns.catplot(x='Pclass', y='Survived', data=df_taitanic, kind='point', hue='person')

# %%
df_taitanic[ (df_taitanic['person']=='child') & (df_taitanic['Pclass']==1)  ].mean()
# Out:
# PassengerId    4.965000e+02
# Survived       8.333333e-01
# Pclass         1.000000e+00
# Age            7.820000e+00
# SibSp          6.666667e-01
# Parch          1.833333e+00
# Ticket         1.896352e+32
# Fare           1.393826e+02
# dtype: float64

# %%
df_taitanic[ (df_taitanic['person']=='female') & (df_taitanic['Pclass']==1)  ].mean()
# Out:
# PassengerId    469.032967
# Survived         0.978022
# Pclass           1.000000
# Age             35.500000
# SibSp            0.549451
# Parch            0.417582
# Fare           104.317995
# dtype: float64

# %%
def survived_ratio(person, pclass):
    return df_taitanic[ (df_taitanic['person']== person ) & (df_taitanic['Pclass']==pclass)  ].mean()[['Pclass','Survived','Age']]

# %%
survived_ratio('female', 1)
# Out:
# Pclass       1.000000
# Survived     0.978022
# Age         35.500000
# dtype: float64

# %%
survived_ratio('female', 2)
# Out:
# Pclass       2.000000
# Survived     0.909091
# Age         32.179688
# dtype: float64

# %%
survived_ratio('female', 3)
# Out:
# Pclass       3.000000
# Survived     0.491228
# Age         27.854167
# dtype: float64

# %% [markdown]
# # 10月26日

# %%
# データの読み込み
import pandas as pd

df_ = pd.read_csv('train.csv')
df_
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.catplot('Pclass', 'Survived', data=df_taitanic, kind='point')
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('Pclass', 'Survived', data=df_taitanic, 
            kind='point', hue='person',aspect=2)
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 回帰曲線を使って性別、年齢、客室の等級の生存率を確認

# %%
generations = [10, 20, 30, 40, 50, 60, 70, 80, 90]

sns.lmplot('Age', 'Survived', data=df_taitanic, 
           hue='Pclass')
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
generations = [10, 20, 30, 40, 50, 60, 70, 80, 90]

sns.lmplot('Age', 'Survived', data=df_taitanic, 
           hue='Pclass', x_bins=generations)
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Age','Survived',data=df_taitanic,hue='Pclass',
           col='person',x_bins=generations)
# Out:
# c:\users\81801\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x='Alone', data=df_taitanic[df_taitanic['person']=='child'])
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
sns.countplot(x='Alone', data=df_taitanic[df_taitanic['person']=='female'])
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
sns.countplot(x='Alone', data=df_taitanic[df_taitanic['person']=='male'])
# Out:
# <AxesSubplot:xlabel='Alone', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x='Age', y='Survived', data=df_taitanic, hue='person',
           x_bins=generations, col='Alone')

plt.ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
